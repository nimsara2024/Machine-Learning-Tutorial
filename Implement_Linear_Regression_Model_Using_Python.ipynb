# %% [markdown]
# <a href="https://colab.research.google.com/github/nimsara2024/Machine-Learning-Tutorial/blob/main/Implement_Linear_Regression_Model_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
